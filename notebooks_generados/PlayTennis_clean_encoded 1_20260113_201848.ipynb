# %% [markdown]
# # Estadística
# Generated by AI Agent.

# %% [markdown]
# ## Carga

# %%
import pandas as pd
df = pd.read_csv('PlayTennis_clean_encoded 1.csv')

# %% [markdown]
# ## Stats

# %%
print(df.describe())

# %% [markdown]
# ## Gráficos

# %%
df.hist()
plt.show()
