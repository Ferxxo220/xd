# %% [markdown]
# # Estadística
# Generated by AI Agent.

# %% [markdown]
# ## Carga

# %%
import pandas as pd
df = pd.read_csv('iris.csv')

# %% [markdown]
# ## Stats

# %%
print(df.describe())

# %% [markdown]
# ## Gráficos

# %%
df.hist()
plt.show()
