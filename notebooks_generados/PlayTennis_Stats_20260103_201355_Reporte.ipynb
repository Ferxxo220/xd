# %% [markdown]
# # Estadística - PlayTennis
#
# **Archivo Original:** `PlayTennis_Stats.csv`
#
# **Generado por:** Agente de Análisis.

# %% [markdown]
# ## Carga

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_csv('PlayTennis.csv')
print('Datos cargados')

# %% [markdown]
# ## Estadísticas

# %%
print(df.describe(include='all').to_string())

# %% [markdown]
# ## Gráficas

# %%
df.select_dtypes(include=['number']).hist(figsize=(10, 6))
plt.show()
