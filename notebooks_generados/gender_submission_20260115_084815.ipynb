# %% [markdown]
# # Preprocesamiento Full
# Generated by AI Agent.

# %% [markdown]
# ## Carga de Datos

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('gender_submission.csv')

# %% [markdown]
# ## Limpieza de Nulos

# %%
# Imputación de nulos
df.fillna(method='ffill', inplace=True)

# %% [markdown]
# ## Eliminación Outliers

# %%
# Filtro Outliers IQR

# %% [markdown]
# ## Exportar CSV Limpio

# %%
df.to_csv('gender_submission_clean_encoded.csv', index=False)
