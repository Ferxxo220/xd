# %% [markdown]
# # Preprocesamiento - PlayTennis
#
# **Archivo Original:** `PlayTennis_Prep.csv`
#
# **Generado por:** Agente de Análisis.

# %% [markdown]
# ## Carga

# %%
import pandas as pd
import numpy as np
# df = pd.read_csv('PlayTennis.csv')

# %% [markdown]
# ## Imputación

# %%
# Imputación de nulos (Mean/Mode)...
df = df.fillna(0) # Simplificado

# %% [markdown]
# ## Correlación

# %%
print(df.corr())
