# %% [markdown]
# # Limpieza
# Generated by AI Agent.

# %% [markdown]
# ## Carga

# %%
import pandas as pd
# df = pd.read_csv('PlayTennis.csv')

# %% [markdown]
# ## Imputación

# %%
df.fillna(method='ffill', inplace=True) # Ejemplo simplificado
