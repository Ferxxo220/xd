# %% [markdown]
# # Preprocesamiento Full
# Generated by AI Agent.

# %% [markdown]
# ## Carga de Datos

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('PlayTennis.csv')

# %% [markdown]
# ## Limpieza de Nulos

# %%
# Imputación de nulos
df.fillna(method='ffill', inplace=True)

# %% [markdown]
# ## Eliminación Outliers

# %%
# Filtro Outliers IQR
# (Código omitido por brevedad, ver notebook completo)

# %% [markdown]
# ## Encoding Automático (Texto -> Num)

# %%
# Encoding: Texto a Números
for c in df.select_dtypes('object').columns:
    df[c] = df[c].astype('category').cat.codes

# %% [markdown]
# ## Exportar CSV Limpio

# %%
df.to_csv('PlayTennis_clean_encoded.csv', index=False)
